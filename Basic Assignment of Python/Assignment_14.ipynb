# %%
#1. What does RGBA stand for?
'''
RGBA is a four-channel format containing data for Red, Green, Blue, and an Alpha value.
The opacity of the color can be easily be controlled by specifying the opacity in terms of a parameter.
Example: The rgba(255, 0, 0, 0.3) defines the red color with opacity set to 0.3
'''

# %%
#2. From the Pillow module, how do you get the RGBA value of any images?
'''
   from PIL import Image
   img = Image.open(‘image.png’)
   rgba = img.convert(“RGBA”)
   datas = rgba.getdata()
'''

# %%
#3. What is a box tuple, and how does it work?
'''
Many of Pillow’s functions and methods take a box tuple argument. 
This means Pillow is expecting a tuple of four integer coordinates that represent a rectangular region in an image. 
The four integers are, in order, as follows:
  
    Left: The x-coordinate of the leftmost edge of the box.

    Top: The y-coordinate of the top edge of the box.

    Right: The x-coordinate of one pixel to the right of the rightmost edge of the box. 
           This integer must be greater than the left integer.

    Bottom: The y-coordinate of one pixel lower than the bottom edge of the box. 
            This integer must be greater than the top integer.

box tuple(3,1,9,6)
3: x cord. of the leftmost edge of the box
1: y cord. of top edge of box 
9: x cord. of one pixel to the right of rightmost edge
6: y cord. of one pixel to the bottom edge
'''

# %%
#4. Use your image and load in notebook then, How can you find out the width and height of an Image object?
# !pip install PIL
from PIL import Image
image1 = Image.open('C:/Users/Mayank/Pictures/joker.jpg')
height , width = image1.size
print("height:",height)
print("width:",width)
# Out:
# height: 670
# width: 377
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
#5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

image1.crop((100, 5, 565, 360))
# Out:
# <PIL.Image.Image image mode=RGB size=465x355 at 0x1C8825A9880>

# %%
#6. After making changes to an Image object, how could you save it as an image file?
'''
Image.save() can be used to save the image with appropriate extention
Image.save(img.png)
'''

# %%
#7. What module contains Pillow’s shape-drawing code?
'''
ImageDraw module
'''

# %%
#8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
'''
first we need to make a image object for example:
im = Image.new('RGBA',(200,200),'white')
now we need to pass this object to the ImageDraw.Draw() method to obtain the 
draw object as follows and use its functions
draw = ImageDraw.Draw(im)
draw.rectangle((20, 30, 60, 60), fill='blue'))
'''

# %%
from PIL import ImageDraw
im = Image.new('RGBA',(200,200),'black')
In [23]:
draw = ImageDraw.Draw(im)
In [24]:
draw.rectangle((20, 30, 60, 60), fill='blue')
In [25]:
im.show()
